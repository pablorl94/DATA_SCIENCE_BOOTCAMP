# %%
# Importaciones

import json
import pandas as pd

# %%
# GENERAL

# %%
# Extracción de las coordenadas de un DataFrame

def obtain_coordinates(dataframe, lng_col = "Longitud", lat_col = "Latitud"):
    coordinates = []
    for row in range(len(dataframe)):
        coordinates.append({"lng": dataframe[lng_col][row], 
                            "lat": dataframe[lat_col][row]})
        
    return coordinates

# %%
# Escritura de datos (collection features) en un archivo en formato json

def write_json(data, filename):
    with open(filename, "w") as file:
        json.dump(data, file)
        
def read_json(filename):
    with open(filename) as file:
        json_data = file.read()
    return json.loads(json_data)

# %%
# MAPA DE CALOR

# %%
# Creación de feature de coordenada

def create_feature(coordinates):
    lng, lat = coordinates["lng"], coordinates["lat"]
    feature = {"type": "Feature", 
               "geometry": { "type": "Point", 
                             "coordinates": [lng, lat]}}
    
    return feature

# %%
# Creación de feature collection con una lista de features creadas con create_feature

def create_feature_collection(collection):
    feature_collection = {"type": "FeatureCollection",
                          "features": collection}
    
    return feature_collection

# %%
# Obtiene una colección a partir de un conjunto de coordenadas. Combina #11 y #12

def obtain_feature_collection(coordinates):
    collection = []
    for pair in coordinates:
        collection.append(create_feature(pair))
    
    return create_feature_collection(collection)

# %%
# Obtiene una colección a partir de un DataFrame

def obtain_df_feature_collection(dataframe):
    coordinates = obtain_coordinates(dataframe, 
                                     lng_col = "Longitude", 
                                     lat_col = "Latitude")
    
    return obtain_feature_collection(coordinates)

# %%
# ROUTES

# %%
# Creación de objeto json para las rutas

def create_route_json(coordinates, dtype = "dict"):
    if dtype == "dict":
        coordinates = [[element["lng"], element["lat"]] for element in coordinates]
    elif dtype == "list":
        coordinates = [[element[0], element[1]] for element in coordinates]
        
    route = {"type": "Feature",
             "geometry": {"type": "LineString", 
                          "coordinates": coordinates}}
    return route

# %%
# EJEMPLO DE APLICACIÓN

# %%
danger = pd.read_csv("rojos.csv")
safe = pd.read_csv("azules.csv")

# %%
print(len(danger))
print(len(safe))
# Out:
# 1174
# 73

# %%
danger_data = obtain_df_feature_collection(danger)
safe_data = obtain_df_feature_collection(safe)

# %%
write_json(danger_data, "json_danger")
write_json(safe_data, "json_safe")

# %%
print(read_json("json_danger"))
print(read_json("json_safe"))
# Out:
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.701993, 40.44656]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7032428000000013, 40.4470797]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7051909, 40.447154]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7041845999999996, 40.445997600000005]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7032428000000013, 40.4470797]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7039852999999994, 40.4481584]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.704605900000001, 40.44668789999999]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7046538, 40.4465075]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7051909, 40.447154]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7078983999999995, 40.44712649999999]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7069329, 40.4474201]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7068345999999988, 40.44749960000001]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7107533999999998, 40.4474265]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7106795, 40.44724209999999]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7078983999999995, 40.44712649999999]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7106795, 40.44724209999999]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7105977999999995, 40.446449]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.711163400000001, 40.4463654]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.711657200000001, 40.446769200000006]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7123144, 40.4466963]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7107533999999998, 40.4474265]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7127043, 40.44823499999999]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7106795, 40.44724209999999]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.712652800000001, 40.44683850000001]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7125611000000003, 40.4468036]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7125611000000003, 40.4468036]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.711657200000001, 40.446769200000006]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.711163400000001, 40.4463654]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7106795, 40.44724209999999]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7146508999999996, 40.4477064]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7159437999999994, 40.44820319999999]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7014123, 40.4445166]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.702240800000001, 40.4454409]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7020875, 40.44560680000001]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7003197999999995, 40.4455481]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.703135199999999, 40.445587100000004]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7041845999999996, 40.445997600000005]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.703135199999999, 40.445587100000004]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7046538, 40. ...
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7019097999999997, 40.444196500000004]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.704604799999999, 40.4449104]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7157059, 40.445349799999995]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7149559, 40.445972499999996]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7019097999999997, 40.444196500000004]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7205436, 40.43168219999999]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7019097999999997, 40.444196500000004]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7030959, 40.4466198]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7006763, 40.4438781]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.704604799999999, 40.4449104]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7097111999999988, 40.447864200000005]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7086782999999994, 40.448947]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7159437999999994, 40.4469317]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7148154000000004, 40.4458389]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7154525, 40.443900899999996]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7112361999999988, 40.44082969999999]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7164697999999996, 40.44112979999999]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7119788000000002, 40.441018400000004]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7119192999999986, 40.44262979999999]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.711934, 40.441151]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7151008999999986, 40.4431369]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7119788000000002, 40.441018400000004]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7164741999999986, 40.4411335]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7162867999999993, 40.4404619]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.717261, 40.443042999999996]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7092674, 40.4357287]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7171696000000014, 40.4387662]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7204516000000014, 40.4426469]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7177054, 40.4426616]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7199525999999996, 40.44518679999999]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7191832000000002, 40.4462184]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.71474, 40.44891430000001]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7147542999999996, 40.448877100000004]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7201599, 40.4449068]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.720000000000001, 40.44527780000001]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7003011, 40.440145]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.713337199999999, 40.4463638]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7081150000000003, 40.450041]}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-3.7149 ...
